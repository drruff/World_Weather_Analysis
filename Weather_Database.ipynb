# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Create an empty list to hold the weather data.
city_weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_weather_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | aykhal
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | leningradskiy
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | tessalit
# Processing Record 8 of Set 1 | namibe
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | hay river
# Processing Record 13 of Set 1 | moron
# Processing Record 14 of Set 1 | nuuk
# Processing Record 15 of Set 1 | zanjan
# Processing Record 16 of Set 1 | port hedland
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | pisco
# Processing Record 19 of Set 1 | viedma
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | solton
# Processing Record 25 of Set 1 | chernyshevskiy
# Processing Record 26 of Set 1 | semnan
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | severnoye
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | alta floresta
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | port-cartier
# Processing Record 36 of Set 1 | denpasar
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | oxelosund
# Processing Record 40 of Set 1 | nouadhibou
# Processing Record 41 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 1 | nevel
# Processing Record 43 of Set 1 | tricase
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | zhezkazgan
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | asau
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | igarka
# Processing Record 50 of Set 1 | krasnovka
# Processing Record 1 of Set 2 | flin flon
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | bajil
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | bereda
# Processing Record 10 of Set 2 | itarema
# Processing Record 11 of Set 2 | awjilah
# Processing Record 12 of Set 2 | kurchum
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | guanare
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | rondonopolis
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | puurmani
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | adrar
# Processing Record 30 of Set 2 | kununurra
# Processing Record 31 of Set 2 | manzil tamim
# City not found. Skipping...
# Processing Record 32 of Set 2 | goslar
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | mandera
# Processing Record 36 of Set 2 | poum
# Processing Record 37 of Set 2 | valdepenas
# Processing Record 38 of Set 2 | cefalu
# Processing Record 39 of Set 2 | mende
# Processing Record 40 of Set 2 | karatuzskoye
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | tungor
# Processing Record 43 of Set 2 | labuhan
# Processing Record 44 of Set 2 | znojmo
# Processing Record 45 of Set 2 | tarko-sale
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | havoysund
# Processing Record 48 of Set 2 | muncar
# Processing Record 49 of Set 2 | haines junction
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | lisakovsk
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | iracoubo
# Processing Record 5 of Set 3 | portland
# Processing Record 6 of Set 3 | hambantota
# Processing Record 7 of Set 3 | maragogi
# Processing Record 8 of Set 3 | amga
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | tulun
# Processing Record 12 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 13 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 3 | amazar
# Processing Record 15 of Set 3 | mildura
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | cootamundra
# Processing Record 20 of Set 3 | lufilufi
# Processing Record 21 of Set 3 | pingdu
# Processing Record 22 of Set 3 | biu
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | maldonado
# Processing Record 26 of Set 3 | zastavna
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | skjervoy
# Processing Record 29 of Set 3 | narsaq
# Processing Record 30 of Set 3 | aswan
# Processing Record 31 of Set 3 | port lincoln
# Processing Record 32 of Set 3 | pronsk
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | fare
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | sinnamary
# Processing Record 38 of Set 3 | nishihara
# Processing Record 39 of Set 3 | iquique
# Processing Record 40 of Set 3 | kungurtug
# Processing Record 41 of Set 3 | palana
# Processing Record 42 of Set 3 | suratgarh
# Processing Record 43 of Set 3 | galesong
# Processing Record 44 of Set 3 | agadir
# Processing Record 45 of Set 3 | pangnirtung
# Processing Record 46 of Set 3 | cockburn town
# Processing Record 47 of Set 3 | sur
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | nantucket
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | yuancheng
# Processing Record 3 of Set 4 | sfantu gheorghe
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | choya
# Processing Record 6 of Set 4 | faya
# Processing Record 7 of Set 4 | garissa
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 4 | sistranda
# Processing Record 12 of Set 4 | saint anthony
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | nacala
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | rawson
# Processing Record 19 of Set 4 | sault sainte marie
# Processing Record 20 of Set 4 | khawhai
# Processing Record 21 of Set 4 | broome
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | qaqortoq
# Processing Record 25 of Set 4 | meulaboh
# Processing Record 26 of Set 4 | dong xoai
# Processing Record 27 of Set 4 | plessisville
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | abu dhabi
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 4 | ahipara
# Processing Record 41 of Set 4 | vigrestad
# Processing Record 42 of Set 4 | port hardy
# Processing Record 43 of Set 4 | henties bay
# Processing Record 44 of Set 4 | lavumisa
# Processing Record 45 of Set 4 | meadow lake
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | camalu
# Processing Record 48 of Set 4 | san juan
# Processing Record 49 of Set 4 | komsomolskiy
# Processing Record 50 of Set 4 | coihueco
# Processing Record 1 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | caceres
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | bugene
# Processing Record 7 of Set 5 | egvekinot
# Processing Record 8 of Set 5 | mayumba
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | puerto del rosario
# Processing Record 12 of Set 5 | kamina
# Processing Record 13 of Set 5 | prescott
# Processing Record 14 of Set 5 | santa cruz de la palma
# Processing Record 15 of Set 5 | koundara
# Processing Record 16 of Set 5 | horki
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | la ronge
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | aksu
# Processing Record 21 of Set 5 | fort nelson
# Processing Record 22 of Set 5 | sulangan
# Processing Record 23 of Set 5 | porto novo
# Processing Record 24 of Set 5 | rio verde de mato grosso
# Processing Record 25 of Set 5 | catio
# Processing Record 26 of Set 5 | kloulklubed
# Processing Record 27 of Set 5 | abu samrah
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | svetlaya
# Processing Record 32 of Set 5 | baglan
# Processing Record 33 of Set 5 | ambulu
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 5 | abalak
# Processing Record 38 of Set 5 | jiexiu
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | alaca
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | tuburan
# Processing Record 43 of Set 5 | camacha
# Processing Record 44 of Set 5 | nalut
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | am timan
# Processing Record 47 of Set 5 | gisborne
# Processing Record 48 of Set 5 | archidona
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | algeciras
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | sao felix do xingu
# Processing Record 4 of Set 6 | maumere
# Processing Record 5 of Set 6 | acapulco
# Processing Record 6 of Set 6 | hoi an
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | vanderhoof
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | nong khai
# Processing Record 13 of Set 6 | mayo
# Processing Record 14 of Set 6 | glendive
# Processing Record 15 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 6 | sanmenxia
# Processing Record 17 of Set 6 | santa cruz
# Processing Record 18 of Set 6 | marshfield
# Processing Record 19 of Set 6 | dingle
# Processing Record 20 of Set 6 | kuytun
# Processing Record 21 of Set 6 | noumea
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | farafangana
# Processing Record 24 of Set 6 | morondava
# Processing Record 25 of Set 6 | zyryanka
# Processing Record 26 of Set 6 | rocha
# Processing Record 27 of Set 6 | atbasar
# Processing Record 28 of Set 6 | udachnyy
# Processing Record 29 of Set 6 | nemuro
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | eyl
# Processing Record 32 of Set 6 | sakaiminato
# Processing Record 33 of Set 6 | paamiut
# Processing Record 34 of Set 6 | arlit
# Processing Record 35 of Set 6 | mae sai
# Processing Record 36 of Set 6 | yenagoa
# Processing Record 37 of Set 6 | allapalli
# Processing Record 38 of Set 6 | navalmoral de la mata
# Processing Record 39 of Set 6 | visnes
# Processing Record 40 of Set 6 | zhangye
# Processing Record 41 of Set 6 | halifax
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | seymchan
# Processing Record 44 of Set 6 | mathbaria
# Processing Record 45 of Set 6 | green valley
# Processing Record 46 of Set 6 | bud
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | seydi
# Processing Record 49 of Set 6 | ken caryl
# Processing Record 50 of Set 6 | kapchorwa
# Processing Record 1 of Set 7 | ucluelet
# Processing Record 2 of Set 7 | massape
# Processing Record 3 of Set 7 | klaksvik
# Processing Record 4 of Set 7 | beloha
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | avera
# Processing Record 7 of Set 7 | toora-khem
# Processing Record 8 of Set 7 | batavia
# Processing Record 9 of Set 7 | millinocket
# Processing Record 10 of Set 7 | nueva gerona
# Processing Record 11 of Set 7 | port alfred
# Processing Record 12 of Set 7 | tilichiki
# Processing Record 13 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 7 | coquimbo
# Processing Record 15 of Set 7 | bereznik
# Processing Record 16 of Set 7 | bitam
# Processing Record 17 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | georgetown
# Processing Record 20 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 7 | salinopolis
# Processing Record 22 of Set 7 | upernavik
# Processing Record 23 of Set 7 | cururupu
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | swan hill
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | saint-pierre
# Processing Record 28 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 7 | longyearbyen
# Processing Record 30 of Set 7 | sabzevar
# Processing Record 31 of Set 7 | ballina
# Processing Record 32 of Set 7 | mogadishu
# Processing Record 33 of Set 7 | cairns
# Processing Record 34 of Set 7 | plettenberg bay
# Processing Record 35 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 7 | ganzhou
# Processing Record 37 of Set 7 | lompoc
# Processing Record 38 of Set 7 | baglung
# Processing Record 39 of Set 7 | rawlins
# Processing Record 40 of Set 7 | lar
# Processing Record 41 of Set 7 | port keats
# Processing Record 42 of Set 7 | zhanaozen
# Processing Record 43 of Set 7 | richards bay
# Processing Record 44 of Set 7 | chabahar
# Processing Record 45 of Set 7 | kasongo-lunda
# Processing Record 46 of Set 7 | byron bay
# Processing Record 47 of Set 7 | iquitos
# Processing Record 48 of Set 7 | hirara
# Processing Record 49 of Set 7 | wakema
# Processing Record 50 of Set 7 | kerema
# Processing Record 1 of Set 8 | burgeo
# Processing Record 2 of Set 8 | barrow
# Processing Record 3 of Set 8 | abadiania
# Processing Record 4 of Set 8 | healdsburg
# Processing Record 5 of Set 8 | qostanay
# Processing Record 6 of Set 8 | north platte
# Processing Record 7 of Set 8 | quevedo
# Processing Record 8 of Set 8 | te anau
# Processing Record 9 of Set 8 | tchamba
# Processing Record 10 of Set 8 | morristown
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | fonte boa
# Processing Record 13 of Set 8 | beyneu
# Processing Record 14 of Set 8 | cornwall
# Processing Record 15 of Set 8 | oranjemund
# Processing Record 16 of Set 8 | trairi
# Processing Record 17 of Set 8 | manyana
# Processing Record 18 of Set 8 | ceuasul-de campie
# City not found. Skipping...
# Processing Record 19 of Set 8 | dhidhdhoo
# Processing Record 20 of Set 8 | shemursha
# Processing Record 21 of Set 8 | chikoy
# City not found. Skipping...
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | itoman
# Processing Record 24 of Set 8 | zhangjiakou
# Processing Record 25 of Set 8 | garowe
# Processing Record 26 of Set 8 | karasuk
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | malakal
# Processing Record 29 of Set 8 | san martin
# Processing Record 30 of Set 8 | kilrush
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | jackson
# Processing Record 33 of Set 8 | pringsewu
# Processing Record 34 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 8 | the valley
# Processing Record 36 of Set 8 | port macquarie
# Processing Record 37 of Set 8 | dakar
# Processing Record 38 of Set 8 | mana
# Processing Record 39 of Set 8 | alyangula
# Processing Record 40 of Set 8 | maracas
# Processing Record 41 of Set 8 | kurtamysh
# Processing Record 42 of Set 8 | gillette
# Processing Record 43 of Set 8 | linhares
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | atar
# Processing Record 46 of Set 8 | muros
# Processing Record 47 of Set 8 | praya
# Processing Record 48 of Set 8 | deputatskiy
# Processing Record 49 of Set 8 | prieska
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | gao
# Processing Record 2 of Set 9 | quimper
# Processing Record 3 of Set 9 | annau
# Processing Record 4 of Set 9 | bolshaya vishera
# City not found. Skipping...
# Processing Record 5 of Set 9 | soyo
# Processing Record 6 of Set 9 | magistralnyy
# Processing Record 7 of Set 9 | kruisfontein
# Processing Record 8 of Set 9 | ponnani
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | buala
# Processing Record 11 of Set 9 | sept-iles
# Processing Record 12 of Set 9 | miracema do tocantins
# Processing Record 13 of Set 9 | berlevag
# Processing Record 14 of Set 9 | noyabrsk
# Processing Record 15 of Set 9 | khorixas
# Processing Record 16 of Set 9 | yala
# Processing Record 17 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 9 | zhigansk
# Processing Record 19 of Set 9 | spokane
# Processing Record 20 of Set 9 | awbari
# Processing Record 21 of Set 9 | uvira
# Processing Record 22 of Set 9 | kozlovo
# Processing Record 23 of Set 9 | sterlitamak
# Processing Record 24 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 9 | camana
# Processing Record 26 of Set 9 | beringovskiy
# Processing Record 27 of Set 9 | faanui
# Processing Record 28 of Set 9 | tadine
# Processing Record 29 of Set 9 | merauke
# Processing Record 30 of Set 9 | nelson
# Processing Record 31 of Set 9 | barra patuca
# Processing Record 32 of Set 9 | antofagasta
# Processing Record 33 of Set 9 | hoa binh
# Processing Record 34 of Set 9 | odweyne
# Processing Record 35 of Set 9 | thinadhoo
# Processing Record 36 of Set 9 | tulsipur
# Processing Record 37 of Set 9 | sansai
# City not found. Skipping...
# Processing Record 38 of Set 9 | zarasai
# Processing Record 39 of Set 9 | chapada dos guimaraes
# Processing Record 40 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | maraa
# Processing Record 42 of Set 9 | vilhena
# Processing Record 43 of Set 9 | san pedro
# Processing Record 44 of Set 9 | krasnoselkup
# Processing Record 45 of Set 9 | port huron
# Processing Record 46 of Set 9 | san buenaventura
# Processing Record 47 of Set 9 | pangai
# Processing Record 48 of Set 9 | gimli
# Processing Record 49 of Set 9 | telimele
# Processing Record 50 of Set 9 | san patricio
# Processing Record 1 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 10 | tomino
# Processing Record 3 of Set 10 | mingguang
# Processing Record 4 of Set 10 | wolgast
# Processing Record 5 of Set 10 | bichura
# Processing Record 6 of Set 10 | umm lajj
# Processing Record 7 of Set 10 | rorvik
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 10 | maksi
# Processing Record 11 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 10 | debre sina
# Processing Record 13 of Set 10 | killybegs
# Processing Record 14 of Set 10 | havelock
# Processing Record 15 of Set 10 | tuy hoa
# Processing Record 16 of Set 10 | milton
# Processing Record 17 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 10 | esna
# Processing Record 19 of Set 10 | pulaski
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | inuvik
# Processing Record 22 of Set 10 | talnakh
# Processing Record 23 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 10 | vaitape
# Processing Record 25 of Set 10 | arivonimamo
# Processing Record 26 of Set 10 | kargat
# Processing Record 27 of Set 10 | gizo
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | akdepe
# Processing Record 30 of Set 10 | mercedes
# Processing Record 31 of Set 10 | inta
# Processing Record 32 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 10 | vao
# Processing Record 34 of Set 10 | ottawa
# Processing Record 35 of Set 10 | quang ngai
# Processing Record 36 of Set 10 | yinchuan
# Processing Record 37 of Set 10 | kalamare
# Processing Record 38 of Set 10 | komatipoort
# Processing Record 39 of Set 10 | cherskiy
# Processing Record 40 of Set 10 | kampot
# Processing Record 41 of Set 10 | wattegama
# Processing Record 42 of Set 10 | suntar
# Processing Record 43 of Set 10 | kilmez
# City not found. Skipping...
# Processing Record 44 of Set 10 | shingu
# Processing Record 45 of Set 10 | shenjiamen
# Processing Record 46 of Set 10 | sumenep
# Processing Record 47 of Set 10 | anadyr
# Processing Record 48 of Set 10 | lata
# Processing Record 49 of Set 10 | cao bang
# Processing Record 50 of Set 10 | kulhudhuffushi
# Processing Record 1 of Set 11 | evensk
# Processing Record 2 of Set 11 | vardo
# Processing Record 3 of Set 11 | boende
# Processing Record 4 of Set 11 | tiznit
# Processing Record 5 of Set 11 | asyut
# Processing Record 6 of Set 11 | lloydminster
# Processing Record 7 of Set 11 | san jose
# Processing Record 8 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 11 | cabo san lucas
# Processing Record 10 of Set 11 | liwale
# Processing Record 11 of Set 11 | atasu
# Processing Record 12 of Set 11 | santiago del estero
# Processing Record 13 of Set 11 | north bend
# Processing Record 14 of Set 11 | chadiza
# Processing Record 15 of Set 11 | ekuvukeni
# Processing Record 16 of Set 11 | kostomuksha
# Processing Record 17 of Set 11 | san cristobal
# Processing Record 18 of Set 11 | vostok
# Processing Record 19 of Set 11 | mandalgovi
# Processing Record 20 of Set 11 | muli
# Processing Record 21 of Set 11 | yakima
# Processing Record 22 of Set 11 | yugo-kamskiy
# Processing Record 23 of Set 11 | antsirabe
# Processing Record 24 of Set 11 | griffith
# Processing Record 25 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 11 | bogorodskoye
# Processing Record 27 of Set 11 | black river
# Processing Record 28 of Set 11 | ugoofaaru
# Processing Record 29 of Set 11 | staffanstorp
# Processing Record 30 of Set 11 | kasempa
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | kenai
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | ormara
# Processing Record 35 of Set 11 | clonakilty
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | ust-nera
# Processing Record 38 of Set 11 | kampene
# Processing Record 39 of Set 11 | saryg-sep
# Processing Record 40 of Set 11 | hanover
# Processing Record 41 of Set 11 | tombouctou
# Processing Record 42 of Set 11 | oyama
# Processing Record 43 of Set 11 | male
# Processing Record 44 of Set 11 | stavern
# Processing Record 45 of Set 11 | onega
# Processing Record 46 of Set 11 | merritt island
# Processing Record 47 of Set 11 | el escorial
# Processing Record 48 of Set 11 | sri aman
# Processing Record 49 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 50 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 12 | fremont
# Processing Record 2 of Set 12 | smoky lake
# Processing Record 3 of Set 12 | sibolga
# Processing Record 4 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 12 | turtas
# Processing Record 6 of Set 12 | cap malheureux
# Processing Record 7 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 8 of Set 12 | korhogo
# Processing Record 9 of Set 12 | turukhansk
# Processing Record 10 of Set 12 | frei paulo
# Processing Record 11 of Set 12 | bako
# Processing Record 12 of Set 12 | zholymbet
# Processing Record 13 of Set 12 | abiy adi
# City not found. Skipping...
# Processing Record 14 of Set 12 | mitsamiouli
# Processing Record 15 of Set 12 | whitehorse
# Processing Record 16 of Set 12 | bintulu
# Processing Record 17 of Set 12 | green river
# Processing Record 18 of Set 12 | gwadar
# Processing Record 19 of Set 12 | iranshahr
# Processing Record 20 of Set 12 | locri
# Processing Record 21 of Set 12 | machhlishahr
# Processing Record 22 of Set 12 | khani
# Processing Record 23 of Set 12 | sicamous
# Processing Record 24 of Set 12 | kachug
# Processing Record 25 of Set 12 | tsiroanomandidy
# Processing Record 26 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 12 | bom jesus
# Processing Record 28 of Set 12 | jutai
# Processing Record 29 of Set 12 | kirkwood
# Processing Record 30 of Set 12 | vestmannaeyjar
# Processing Record 31 of Set 12 | gacko
# Processing Record 32 of Set 12 | ventspils
# Processing Record 33 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 12 | santa fe
# Processing Record 35 of Set 12 | tuatapere
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | natal
# Processing Record 38 of Set 12 | iskateley
# Processing Record 39 of Set 12 | port alberni
# Processing Record 40 of Set 12 | ponta delgada
# Processing Record 41 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 12 | gamba
# Processing Record 43 of Set 12 | luba
# Processing Record 44 of Set 12 | rio gallegos
# Processing Record 45 of Set 12 | rapid valley
# Processing Record 46 of Set 12 | tahoua
# Processing Record 47 of Set 12 | mitu
# Processing Record 48 of Set 12 | lamu
# Processing Record 49 of Set 12 | roald
# Processing Record 50 of Set 12 | maceio
# Processing Record 1 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 13 | omsukchan
# Processing Record 3 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 13 | price
# Processing Record 5 of Set 13 | prestea
# Processing Record 6 of Set 13 | mandaguari
# Processing Record 7 of Set 13 | esperance
# Processing Record 8 of Set 13 | terekli-mekteb
# Processing Record 9 of Set 13 | mahibadhoo
# Processing Record 10 of Set 13 | taldan
# Processing Record 11 of Set 13 | huntingdon
# Processing Record 12 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 13 | namwala
# Processing Record 14 of Set 13 | bonfim
# Processing Record 15 of Set 13 | conceicao do araguaia
# Processing Record 16 of Set 13 | okha
# Processing Record 17 of Set 13 | quilali
# Processing Record 18 of Set 13 | dubrovka
# Processing Record 19 of Set 13 | rundu
# Processing Record 20 of Set 13 | lethem
# Processing Record 21 of Set 13 | kapoeta
# Processing Record 22 of Set 13 | lincoln
# Processing Record 23 of Set 13 | atuntaqui
# Processing Record 24 of Set 13 | colquechaca
# Processing Record 25 of Set 13 | ystad
# Processing Record 26 of Set 13 | oktyabrskoye
# Processing Record 27 of Set 13 | los llanos de aridane
# Processing Record 28 of Set 13 | nago
# Processing Record 29 of Set 13 | campo grande
# Processing Record 30 of Set 13 | kimparana
# Processing Record 31 of Set 13 | bilibino
# Processing Record 32 of Set 13 | pallasovka
# Processing Record 33 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 13 | molokovo
# Processing Record 35 of Set 13 | zaysan
# Processing Record 36 of Set 13 | urumqi
# Processing Record 37 of Set 13 | pitimbu
# Processing Record 38 of Set 13 | rossland
# Processing Record 39 of Set 13 | marsh harbour
# Processing Record 40 of Set 13 | columbus
# Processing Record 41 of Set 13 | samarai
# Processing Record 42 of Set 13 | axim
# Processing Record 43 of Set 13 | badaojiang
# City not found. Skipping...
# Processing Record 44 of Set 13 | kuva
# City not found. Skipping...
# Processing Record 45 of Set 13 | osoyoos
# Processing Record 46 of Set 13 | talara
# Processing Record 47 of Set 13 | nabire
# Processing Record 48 of Set 13 | rancho palos verdes
# Processing Record 49 of Set 13 | nhulunbuy
# Processing Record 50 of Set 13 | kurbnesh
# Processing Record 1 of Set 14 | usinsk
# Processing Record 2 of Set 14 | ankara
# Processing Record 3 of Set 14 | bainbridge
# Processing Record 4 of Set 14 | marsa matruh
# Processing Record 5 of Set 14 | boyolangu
# Processing Record 6 of Set 14 | qarqin
# Processing Record 7 of Set 14 | seoul
# Processing Record 8 of Set 14 | buta
# Processing Record 9 of Set 14 | vrangel
# Processing Record 10 of Set 14 | prince rupert
# Processing Record 11 of Set 14 | contamana
# Processing Record 12 of Set 14 | celle
# Processing Record 13 of Set 14 | breves
# Processing Record 14 of Set 14 | thomaston
# Processing Record 15 of Set 14 | oltu
# Processing Record 16 of Set 14 | tura
# Processing Record 17 of Set 14 | paita
# Processing Record 18 of Set 14 | adamovka
# Processing Record 19 of Set 14 | rio pardo
# Processing Record 20 of Set 14 | isilkul
# Processing Record 21 of Set 14 | varkaus
# Processing Record 22 of Set 14 | sturgeon bay
# Processing Record 23 of Set 14 | medicine hat
# Processing Record 24 of Set 14 | paragominas
# Processing Record 25 of Set 14 | itaquyry
# Processing Record 26 of Set 14 | voloshka
# Processing Record 27 of Set 14 | jiayuguan
# Processing Record 28 of Set 14 | fenoarivo
# Processing Record 29 of Set 14 | yumen
# Processing Record 30 of Set 14 | bressuire
# Processing Record 31 of Set 14 | abha
# Processing Record 32 of Set 14 | puntarenas
# Processing Record 33 of Set 14 | gaziantep
# Processing Record 34 of Set 14 | sao filipe
# Processing Record 35 of Set 14 | bure
# Processing Record 36 of Set 14 | madison heights
# Processing Record 37 of Set 14 | taltal
# Processing Record 38 of Set 14 | palmer
# Processing Record 39 of Set 14 | mackay
# Processing Record 40 of Set 14 | prince albert
# Processing Record 41 of Set 14 | mount gambier
# Processing Record 42 of Set 14 | bontang
# Processing Record 43 of Set 14 | hirapur
# Processing Record 44 of Set 14 | zambezi
# Processing Record 45 of Set 14 | cabatuan
# Processing Record 46 of Set 14 | kuybyshevo
# Processing Record 47 of Set 14 | kaeo
# Processing Record 48 of Set 14 | winslow
# Processing Record 49 of Set 14 | powell
# Processing Record 50 of Set 14 | takoradi
# Processing Record 1 of Set 15 | moses lake
# Processing Record 2 of Set 15 | pochutla
# Processing Record 3 of Set 15 | aste
# Processing Record 4 of Set 15 | baykit
# Processing Record 5 of Set 15 | krasnyy oktyabr
# Processing Record 6 of Set 15 | kitui
# Processing Record 7 of Set 15 | parintins
# Processing Record 8 of Set 15 | homer
# Processing Record 9 of Set 15 | bardiyah
# Processing Record 10 of Set 15 | dryden
# Processing Record 11 of Set 15 | ashington
# Processing Record 12 of Set 15 | tual
# Processing Record 13 of Set 15 | ghanzi
# Processing Record 14 of Set 15 | itaituba
# Processing Record 15 of Set 15 | hobyo
# Processing Record 16 of Set 15 | shaoguan
# Processing Record 17 of Set 15 | saint-joseph
# Processing Record 18 of Set 15 | sabang
# Processing Record 19 of Set 15 | los algarrobos
# Processing Record 20 of Set 15 | ixtapa
# Processing Record 21 of Set 15 | grenfell
# Processing Record 22 of Set 15 | odesskoye
# Processing Record 23 of Set 15 | vila franca do campo
# Processing Record 24 of Set 15 | mkuranga
# Processing Record 25 of Set 15 | caluquembe
# Processing Record 26 of Set 15 | ketchikan
# Processing Record 27 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 15 | grandview
# Processing Record 29 of Set 15 | samana
# Processing Record 30 of Set 15 | perez
# Processing Record 31 of Set 15 | cascais
# Processing Record 32 of Set 15 | mayskiy
# Processing Record 33 of Set 15 | todos santos
# Processing Record 34 of Set 15 | ailigandi
# Processing Record 35 of Set 15 | iralaya
# Processing Record 36 of Set 15 | luanda
# Processing Record 37 of Set 15 | shellbrook
# Processing Record 38 of Set 15 | pizarro
# Processing Record 39 of Set 15 | holme
# Processing Record 40 of Set 15 | soe
# Processing Record 41 of Set 15 | kiama
# Processing Record 42 of Set 15 | guerrero negro
# Processing Record 43 of Set 15 | nyurba
# Processing Record 44 of Set 15 | uyuni
# Processing Record 45 of Set 15 | vestmanna
# Processing Record 46 of Set 15 | bemidji
# Processing Record 47 of Set 15 | uige
# Processing Record 48 of Set 15 | la crosse
# Processing Record 49 of Set 15 | ola
# Processing Record 50 of Set 15 | esmeraldas
# Processing Record 1 of Set 16 | ayorou
# Processing Record 2 of Set 16 | la libertad
# Processing Record 3 of Set 16 | dembi dolo
# Processing Record 4 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 16 | manzini
# Processing Record 6 of Set 16 | hohhot
# Processing Record 7 of Set 16 | nikki
# Processing Record 8 of Set 16 | baoning
# Processing Record 9 of Set 16 | sisimiut
# Processing Record 10 of Set 16 | mananjary
# Processing Record 11 of Set 16 | labrador
# Processing Record 12 of Set 16 | xichang
# Processing Record 13 of Set 16 | ajdabiya
# Processing Record 14 of Set 16 | shizilu
# Processing Record 15 of Set 16 | foxton
# Processing Record 16 of Set 16 | trelew
# Processing Record 17 of Set 16 | chifeng
# Processing Record 18 of Set 16 | puerto madryn
# Processing Record 19 of Set 16 | ostroh
# Processing Record 20 of Set 16 | warri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_data_df = pd.DataFrame(city_weather_data)
city_weather_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mahebourg -20.4081   57.7000     73.69        88          75
# 1   Punta Arenas -53.1500  -70.9167     48.31        37           0
# 2         Aykhal  66.0000  111.5000    -49.59       100          98
# 3      Busselton -33.6500  115.3333     55.09        60         100
# 4  Leningradskiy  69.3833  178.4167    -31.25        91           3
# 5       Tessalit  20.1986    1.0114     69.76         9          14
# 6         Namibe -15.1961   12.1522     71.40        77          53
# 7          Bluff -46.6000  168.3333     64.80        71          22
# 8           Chuy -33.6971  -53.4616     68.59        76           0
# 9    East London -33.0153   27.9116     71.85        95         100
#
#    Wind Speed Country Current Description
# 0        3.44      MU       broken clouds
# 1       17.27      CL           clear sky
# 2        6.08      RU     overcast clouds
# 3        8.81      AU     overcast clouds
# 4        4.41      RU           clear sky
# 5        8.93      ML          few clouds
# 6        5.46      AO       broken clouds
# 7        7.27      NZ          few clouds
# 8       13.00      UY          light rain
# 9        7.87      ZA          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_weather_data_df = city_weather_data_df[new_column_order]
city_weather_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mahebourg      MU -20.4081   57.7000     73.69        88          75
# 1   Punta Arenas      CL -53.1500  -70.9167     48.31        37           0
# 2         Aykhal      RU  66.0000  111.5000    -49.59       100          98
# 3      Busselton      AU -33.6500  115.3333     55.09        60         100
# 4  Leningradskiy      RU  69.3833  178.4167    -31.25        91           3
# 5       Tessalit      ML  20.1986    1.0114     69.76         9          14
# 6         Namibe      AO -15.1961   12.1522     71.40        77          53
# 7          Bluff      NZ -46.6000  168.3333     64.80        71          22
# 8           Chuy      UY -33.6971  -53.4616     68.59        76           0
# 9    East London      ZA -33.0153   27.9116     71.85        95         100
#
#    Wind Speed Current Description
# 0        3.44       broken clouds
# 1       17.27           clear sky
# 2        6.08     overcast clouds
# 3        8.81     overcast clouds
# 4        4.41           clear sky
# 5        8.93          few clouds
# 6        5.46       broken clouds
# 7        7.27          few clouds
# 8       13.00          light rain
# 9        7.87          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_data_df.to_csv(output_data_file, index_label="City_ID")
